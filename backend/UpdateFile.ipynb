# %%
import dash                     # pip install dash
from dash.dependencies import Input, Output, State
from dash import dcc
import plotly

import numpy as np

import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#import cufflinks as cf

#import dash_html_components as html
from dash import html
import plotly.express as px     # pip install plotly==5.2.2

import pandas as pd

# %%
df1 = pd.read_csv('Group2Data.csv')

# %%
df1.rename(columns={'energy_cons': 'Energy Consumption','employees': 'Total Employee','waste': 'Waste Produced',
                    'waste_recycled': 'Waste Recycled',
                   'water_cons': 'Water Consumption','waste_water':'Water Wastage','renewable_energy_pct':
                   'Renewable Energy','fuel_fleet':'Fuel Fleet','contrib_political':'Political Contribution',
                   'waste_recycled_pct':'Waste Recycled Percentage',' legal_spending':
                   'Legal Spending','fines_spending':'Fine Spending','employee_turnover':'Employee Turnover',
                   'female_pct' :'Female Percentage','female_mgmt_pct':'Female Management Percentage',
                   'employee_parental_pct':'Employee Parental Percentage','employee_tenure':'Employee Tenure',
                   'employee_under30_pct':'Employee Under30 Percentage',
                   'employee_over50_pct':'Employee Over50 Percentage',
                   'training_spending':'Training spending'}, inplace=True)
df1
# Out:
#     id                     name            Industry  year  scope1_intensity  \
# 0   31            Kion Group AG         Industrials  2020               NaN
# 1   31            Kion Group AG         Industrials  2019               NaN
# 2   22          Gerresheimer AG         Industrials  2021               NaN
# 3   22          Gerresheimer AG         Industrials  2020               NaN
# 4   22          Gerresheimer AG         Industrials  2019               NaN
# ..  ..                      ...                 ...   ...               ...
# 74  72            Deutsche Bank  Financial Services  2019               NaN
# 75  77                Fresenius         Health care  2021               NaN
# 76  77                Fresenius         Health care  2020               NaN
# 77  77                Fresenius         Health care  2019               NaN
# 78  48  Siemens Healthineers AG         Health care  2021               NaN
#
#     scope2_intensity  scope3_intensity     scope_1    scope_2     scope_3  \
# 0                NaN               NaN  67900000.0  4800000.0  21300000.0
# 1                NaN               NaN  72600000.0  4800000.0  22700000.0
# 2                NaN               NaN    280410.0   272082.0    410060.0
# 3                NaN               NaN    275334.0   285092.0    304024.0
# 4                NaN               NaN    264803.0   282724.0    297051.0
# ..               ...               ...         ...        ...         ...
# 74               NaN               NaN     50273.0   104671.0   2127013.0
# 75               NaN               NaN    578000.0   946000.0         NaN
# 76               NaN               NaN    536000.0   976000.0         NaN
# 77               NaN               NaN    522000.0   982000.0         NaN
# 78               NaN               NaN    106000.0   245000.0   3243000.0
#
#     ...  Fine Spending  Total Employee  Employee Turnover  Female Percentage  \
# 0   ...            NaN         53122.0      664025.000000               17.2
# 1   ...            NaN         55047.0      500427.272700               16.7
# 2   ...            NaN         10447.0          15.181392               30.8
# 3   ...            NaN          9880.0          11.973684               33.3
# 4   ...            NaN             NaN                NaN                NaN
# ..  ...            ...             ...                ...                ...
# 74  ...            NaN         87597.0                NaN               46.3
# 75  ...            NaN        316078.0                NaN               69.0
# 76  ...            NaN        311269.0                NaN               68.0
# 77  ...            NaN        294134.0                NaN               68.0
# 78  ...            NaN         55526.0                NaN               31.0
#
#     Female Management Percentage  Employee Parental Percentage  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                       20.20000                           NaN
# 3                       18.00000                           NaN
# 4                            NaN                           NaN
# ..                           ...                           ...
# 74                           NaN                           NaN
# 75                           NaN                           NaN
# 76                           NaN                           NaN
# 77                           NaN                           NaN
# 78                      11.82329                           NaN
#
#     Employee Tenure  Employee Under30 Percentage  Employee Over50 Percentage  \
# 0               NaN                         10.6                        38.1
# 1               NaN                         11.7                        36.5
# 2               NaN                          NaN                         NaN
# 3               NaN                          NaN                         NaN
# 4               NaN                          NaN                         NaN
# ..              ...                          ...                         ...
# 74              NaN                         15.1                        29.2
# 75              NaN                          NaN                         NaN
# 76              NaN                          NaN                         NaN
# 77              NaN                          NaN                         NaN
# 78              NaN                         28.0                        18.0
#
#     Training spending
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 74                NaN
# 75                NaN
# 76                NaN
# 77                NaN
# 78                NaN
#
# [79 rows x 32 columns]

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)


indicators = ['Total Employee','EmployeeTurnover', 'Female Percentage', 'Female Management Percentage',
              'Employee Under30 Percentage','Employee Over50 Percentage',
             'Water Consumption','Waste Produced','scope_1','scope_2','scope_3']




app.layout = html.Div([
    html.H1("German sustainablity model", style={"textAlign":"center"}),
    html.Hr(),
    html.P("By Industry"),
    html.Div(html.Div([
        dcc.Dropdown(id='indus_list', clearable=False,
                     value=["IT"],
                     options=[{'label': x, 'value': x} for x in
                              df1["Industry"].unique()],style={'width': '50%'}
                    )
    ],className="two columns"),className="row"),
    
    html.P("Indicators"),
    html.Div(html.Div([
        dcc.Dropdown(id='indi_list', clearable=False,
                     value="employees",
                     options=[{'label': x, 'value': x} for x in
                              indicators],style={'width': '50%'}),
    ],className="two columns"),className="row"),
    
    html.Div(id="output-div", children=[]),
    

    html.H2("Averages per Industry", style={"textAlign":"center"}),
    html.P("Select Industry"),
    html.Div(html.Div([
        dcc.Dropdown(id='indus_list2', clearable=False,
                     value="Industrials",
                     options=[{'label': x, 'value': x} for x in
                              df1["Industry"].unique()],multi=True,style={'width': '50%'}),
    ],className="one columns"),className="row"),
    html.P("Select Indicator"),
    html.Div(html.Div([
        dcc.Dropdown(id='indi_list2', clearable=False,
                     value="employees",
                     options=[{'label': x, 'value': x} for x in
                              indicators],style={'width': '50%'}),
    ],className="one columns"),className="row"),
    html.Div(id="output-div2", children=[])
    
    
])

# %%
@app.callback(Output(component_id="output-div", component_property="children"),
              
              Input(component_id="indus_list", component_property="value"),
              Input(component_id="indi_list", component_property="value")
              
               
)



def make_graphs(indus_list,ind_chosen):
    
    
    
    #graph1
    df_ind = df1[df1["Industry"]==indus_list]
    
    # LINE CHART
    df_line = df_ind.sort_values(by=[ind_chosen], ascending=True)
    df_line = df_line.groupby(
        ["year","name", ind_chosen]).size().reset_index(name="count")
    #print(df_line.head())
    fig = px.line(df_line, x="year", y=ind_chosen,color='name',markers=True)
    
    return [
        
         
        html.Div([
           html.Div([dcc.Graph(figure=fig)],style={'width': '70%'}, className="six columns"),
        ], className="row"),
        
       
        
    ]
    
    
    #graph2
@app.callback(Output(component_id="output-div2", component_property="children"),            
        
              Input(component_id="indus_list2", component_property="value"),
              Input(component_id="indi_list2", component_property="value")
)

def avg_graph(indus_list2,ind_chosen2):
    
    #meandf = df.groupby(['Industry', 'years']).mean()
    
    # LINE CHART
    #df_line2 = df.sort_values(by=[ind_chosen2], ascending=True)
    #df_line2 = df_line2.groupby(
     #   ["Industry","years", ind_chosen2]).mean()
    #print(df_line.head())
    #fig2 = px.line(df_line2, x="donations", y="years",color='Industry',markers=True)
    
    df_ind1 = df1[df1["Industry"].isin(indus_list2)]
    
    # LINE CHART
    meandf= df_ind1.groupby(['Industry', 'year']).mean().reset_index()
    #print(df_line.head())
    fig2 = px.line(meandf, x='year', y=ind_chosen2,color='Industry',markers=True)
    
    #fig2_1 = px.line(meandf, x='Industry', y=ind_chosen2,color='Industry',markers=True)
    meandf1= df1.groupby(['Industry']).mean().reset_index()
    fig2_1 = px.bar(meandf1, x="Industry", y=ind_chosen2, 
                 color="Industry" )
    return [
        
         
        html.Div([
           html.Div([dcc.Graph(figure=fig2)],style={'width': '90%'}, className="four columns"),
        ], className="row"),
        html.Div([
           html.Div([dcc.Graph(figure=fig2_1)], className="four columns"),
        ], className="row"),
        
        
       
        
    ]
    
    


if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Jul/2022 23:27:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:27:36] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:27:36] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:27:37] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\dash.py", line 1372, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\SHOAIB~1\AppData\Local\Temp/ipykernel_4304/3870246494.py", line 16, in make_graphs
#     df_ind = df1[df1["Industry"]==indus_list]
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\ops\common.py", line 69, in new_method
#     return method(self, other)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\arraylike.py", line 32, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\series.py", line 5502, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 261, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (79,), (1,))
# 127.0.0.1 - - [04/Jul/2022 23:27:37] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\dash.py", line 1372, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\SHOAIB~1\AppData\Local\Temp/ipykernel_4304/3870246494.py", line 55, in avg_graph
#     df_ind1 = df1[df1["Industry"].isin(indus_list2)]
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\series.py", line 5025, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\algorithms.py", line 459, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [04/Jul/2022 23:27:37] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\dash.py", line 1372, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\SHOAIB~1\AppData\Local\Temp/ipykernel_4304/3870246494.py", line 19, in make_graphs
#     df_line = df_ind.sort_values(by=[ind_chosen], ascending=True)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\frame.py", line 6259, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\generic.py", line 1779, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: None
# 127.0.0.1 - - [04/Jul/2022 23:27:37] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\dash.py", line 1372, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\SHOAIB~1\AppData\Local\Temp/ipykernel_4304/3870246494.py", line 55, in avg_graph
#     df_ind1 = df1[df1["Industry"].isin(indus_list2)]
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\series.py", line 5025, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\algorithms.py", line 459, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [04/Jul/2022 23:27:37] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\dash.py", line 1372, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\SHOAIB~1\AppData\Local\Temp/ipykernel_4304/3870246494.py", line 19, in make_graphs
#     df_line = df_ind.sort_values(by=[ind_chosen], ascending=True)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\frame.py", line 6259, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "C:\Users\Shoaib Malik\anaconda3\lib\site-packages\pandas\core\generic.py", line 1779, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: None
# 127.0.0.1 - - [04/Jul/2022 23:27:40] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [04/Jul/2022 23:28:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:07] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:07] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:28:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:29:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:29:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:29:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:29:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jul/2022 23:29:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:20:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:21:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:40:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:40:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:41:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:41:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:41:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:41:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:41:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 08:46:06] "POST /_dash-update-component HTTP/1.1" 200 -
